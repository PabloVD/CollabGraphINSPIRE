# %% [markdown]
# # INSPIRE Collaboration Graph
#
# Scrape publication data from INSPIRE-HEP to create a graph of collaborations using Networkx
#
# Read about the INSPIRE API here: https://github.com/inspirehep/rest-api-doc
#
# Author: Pablo Villanueva-Domingo

# %%
import requests
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Author search routine
# Given a root author rootauthorid, it calls the INSPIRE API to get data about his/her publications
# Then, takes the coauthors and add them to the graph
def author_search(rootauthorid, coauthids, graph, verbose=True):
    
    # Search articles from the profile authorid
    authorquery = 'https://inspirehep.net/api/literature?sort=mostrecent&size=1000&q=a%20'+rootauthorid
    page = requests.get(authorquery)

    # Take the publications
    try:
        data = page.json()["hits"]["hits"]
    except:
        print("Problem reading json data of "+rootauthorid+", skipping")
        return coauthids, graph

    # For each publication, get the coauthors
    for pub in data:

        authors = pub["metadata"]["authors"]
        for authdict in authors:
            
            try:
                inspireid = authdict["ids"][0]["value"]
                full_name = authdict["full_name"]
            except:
                print("Profile "+rootauthorid+" without ids, skipping")
                pass

            # Add to the list if the author is not in the graph yet
            if (inspireid in coauthids)==False:
                if verbose:
                    print(inspireid, full_name)
                
                # Add to the graph as a node, with its correspondent edge to the root author
                graph.add_node(inspireid)
                graph.add_edge(rootauthorid, inspireid)

                coauthids.append(inspireid)
                
            # In case the author is already in the list (found as coauthor of another researcher), add an edge from the current root author
            else:
                graph.add_edge(rootauthorid, inspireid)
            
    return coauthids, graph

# %%
# Given an initial list of authors, create a graph with their coauthors
# Alternatively, one can also start with only one author, and the routine iterates over his/her coauthors over n_auths
def create_coll_graph(ini_coauths, n_auths=None, verbose=True):
    
    coauthids = ini_coauths.copy()
    if n_auths==None:
        n_auths = len(ini_coauths)

    # Create an empty graph
    graph = nx.Graph()

    # Start loop over authors
    count = 0    
    for auth in coauthids:
        print(count,auth)
        coauthids, graph = author_search(auth, coauthids, graph, verbose)
        count+=1
        if count==n_auths:
            break

    # Create a subgraph including only the initial authors
    inigraph = graph.subgraph(ini_coauths)
    print("Number of nodes:", graph.number_of_nodes(), "Number of edges:",  graph.number_of_edges())
    return graph, inigraph

# %%
# Create a initial list of authors
ini_coauths = ["P.Villanueva.Domingo.1","M.G.Folgado.1","N.Rius.1","Stefan.Sandner.1","V.Munoz.2"]

# Create their collaboration graph
graph, inigraph = create_coll_graph(ini_coauths)
# Out:
# 0 P.Villanueva.Domingo.1
# F.Villaescusa.Navarro.1 Villaescusa-Navarro, Francisco
# D.AnglesAlcazar.2 Anglés-Alcázar, Daniel
# Shy.Genel.1 Genel, Shy
# F.Marinacci.4 Marinacci, Federico
# D.N.Spergel.1 Spergel, David N.
# L.E.Hernquist.1 Hernquist, Lars
# M.Vogelsberger.1 Vogelsberger, Mark
# R.Dave.1 Dave, Romeel
# D.Narayanan.1 Narayanan, Desika
# L.Thiele.1 Thiele, Leander
# A.Nicola.1 Nicola, Andrina
# Yin.Li.1 Li, Yin
# B.D.Wandelt.1 Wandelt, Benjamin
# R.S.Somerville.1 Somerville, Rachel S.
# J.M.Z.Matilla.1 Matilla, Jose Manuel Zorrilla
# F.G.Mohammad.1 Mohammad, Faizan G.
# S.Hassan.1 Hassan, Sultan
# H.Shao.1 Shao, Helen
# D.Wadekar.1 Wadekar, Digvijay
# M.Eickenberg.1 Eickenberg, Michael
# K.W.K.Wong.1 Wong, Kaze W.K.
# G.Contardo.1 Contardo, Gabriella
# Y.Jo.2 Jo, Yongseok
# E.Moser.1 Moser, Emily
# E.T.Lau.1 Lau, Erwin T.
# L.F.M.P.Valle.1 Valle, Luis Fernando Machado Poletti
# Alejandro.Perez.2 Perez, Lucia A.
# D.Nagai.1 Nagai, Daisuke
# N.Battaglia.5 Battaglia, Nicholas
# K.Ichiki.2 Ichiki, Kiyotomo
# O.Mena.1 Mena, Olga
# S.Palomares.Ruiz.1 Palomares-Ruiz, Sergio
# 0000-0002-0936-4279 Villanueva-Domingo, Pablo
# 0000-0002-4816-0455 Villaescusa-Navarro, Francisco
# L.Lopez.Honorez.1 Lopez-Honorez, Laura
# Samuel.J.Witte.1 Witte, Samuel J.
# Olga.Mena.1 Mena, Olga
# INSPIRE-00379454 Miralda-Escudé, Jordi
# Stefano.Gariazzo.1 Gariazzo, Stefano
# M.Escudero.1 Escudero, Miguel
# INSPIRE-00049391 Gnedin, Nickolay Y.
# INSPIRE-00057714 Mena, Olga
# Nickolay.Y.Gnedin.1 Gnedin, Nickolay Y.
# 1 M.G.Folgado.1
# 0000-0003-1069-490X Bernal, Nicolás
# 0000-0001-6668-5477 Donini, Andrea
# 0000-0003-1613-5500 Folgado, Miguel G.
# 0000-0002-0606-4297 Rius, Nuria
# A.Donini.1 Donini, Andrea
# 0000-0001-8864-2507 Sanz, Veronica
# INSPIRE-00077776 Donini, Andrea
# G.A.Gomez.Vargas.1 Gómez-Vargas, Germán A.
# R.Ruiz.De.Austri.12 Ruiz De Austri, Roberto
# 2 N.Rius.1
# 0000-0002-4487-8742 Escudero, Miguel
# 0000-0002-9554-5075 Lopez-Pavon, Jacobo
# 0000-0002-1802-9018 Sandner, Stefan
# J.Salvado.1 Salvadó, Jordi
# Andrea.Caputo.1 Caputo, Andrea
# P.Hernandez.1 Hernandez, Pilar
# M.Drewes.1 Drewes, M.
# B.Garbrecht.1 Garbrecht, B.
# M.Kekic.1 Kekic, M.
# J.Lopez.Pavon.1 Lopez-Pavon, J.
# J.Racker.1 Racker, J.
# D.Teresi.1 Teresi, D.
# E.J.Chun.1 Chun, E.J.
# G.Cvetic.1 Cvetič, G.
# P.S.B.Dev.1 Dev, P.S.B.
# Chee.Sheng.Fong.1 Fong, C.S.
# T.Hambye.1 Hambye, T.
# J.Harz.1 Harz, J.
# C.S.Kim.2 Kim, C.S.
# E.Molinaro.1 Molinaro, E.
# E.Nardi.1 Nardi, E.
# Jilberto.Zamora.Saa.1 Zamora-Saa, J.
# Veronica.Sanz.1 Sanz, Verónica
# J.Herrero.Garcia.1 Herrero-Garcia, Juan
# Arcadi.Santamaria.1 Santamaria, Arcadi
# M.Nebot.1 Nebot, Miguel
# M.Pena.1 Pena, Manuel
# A.Aparici.2 Aparici, Alberto
# M.C.Gonzalez.Garcia.1 Gonzalez-Garcia, M.C.
# J.A.Casas.1 Casas, J.Alberto
# J.M.Moreno.1 Moreno, Jesus M.
# R.Ruiz.de.Austri.1 Ruiz de Austri, Roberto
# B.Zaldivar.1 Zaldivar, Bryan
# Rodrigo.Alonso.1 Alonso, Rodrigo
# S.Antusch.1 Antusch, Stefan
# M.Blennow.1 Blennow, Mattias
# P.Coloma.1 Coloma, Pilar
# A.de.Gouvea.1 de Gouvea, Andre
# E.Fernandez.Martinez.1 Fernandez-Martinez, Enrique
# M.B.Gavela.Legazpi.1 Gavela, Belen
# S.Hortner.1 Hortner, Sergio
# INSPIRE-00100256 Laveder, Marco
# Tracey.Chuiyee.Li.1 Li, Tracey
# M.Maltoni.1 Maltoni, Michele
# P.Migliozzi.1 Migliozzi, Pasquale
# Toshihiko.Ota.1 Ota, Toshihiko
# A.Para.1 Para, Adam
# S.J.Parke.1 Parke, Stephen
# T.Schwetz.Mangold.1 Schwetz-Mangold, Thomas
# F.J.P.Soler.1 Soler, F.J.P.
# Michel.Sorel.1 Sorel, Michel
# O.Yasuda.1 Yasuda, Osamu
# Walter.Winter.1 Winter, Walter
# B.Dasgupta.1 Dasgupta, Basudeb
# 0000-0002-6274-4473 Fernandez-Martinez, Enrique
# Z.Girones.1 Girones, Z.
# A.A.Marchetti.1 Marchetti, A.
# C.Pena.Garay.1 Pena-Garay, C.
# J.Garayoa.1 Garayoa, J.
# S.Pastor.2 Pastor, S.
# T.Pinto.1 Pinto, T.
# Oscar.Vives.1 Vives, O.
# S.Davidson.1 Davidson, Sacha
# F.Palorini.1 Palorini, Federica
# INSPIRE-00155305 Gonzalez-Garcia, M.C.
# J.Hirn.1 Hirn, Johannes
# INSPIRE-00115443 Pena-Garay, C.
# Juan.Antonio.Lopez.Perez.1 Lopez-Perez, Juan A.
# Ann.E.Nelson.1 Nelson, Ann E.
# M.Unsal.1 Unsal, Mithat
# S.Forte.2 Forte, S.
# P.Gambino.1 Gambino, P.
# INSPIRE-00160792 Strumia, A.
# M.Losada.1 Losada, Marta
# C.Manuel.1 Manuel, Cristina
# Gabriela.Barenboim.1 Barenboim, Gabriela
# O.Pene.1 Pene, O.
# S.Vargas.Castrillon.1 Vargas-Castrillon, S.
# L.Covi.1 Covi, Laura
# Esteban.Roulet.1 Roulet, Esteban
# F.Vissani.1 Vissani, Francesco
# M.Pietroni.1 Pietroni, M.
# N.Tetradis.1 Tetradis, N.
# INSPIRE-00141857 Randall, Lisa
# INSPIRE-00082355 Freedman, D.Z.
# G.Lozano.1 Lozano, G.
# E.H.Simmons.1 Simmons, Elizabeth H.
# G.V.Dunne.1 Dunne, Gerald V.
# G.Grignani.1 Grignani, Gianluca
# Kenneth.A.Johnson.1 Johnson, Kenneth
# F.del.Aguila.1 del Aguila, F.
# J.Bernabeu.1 Bernabeu, J.
# R.Alemany.2 Alemany, R.
# J.J.Gomez.Cadenas.1 Gomez-Cadenas, J.J.
# A.Pich.1 Pich, A.
# Jorge.Crispim.Romao.1 Romao, J.C.
# INSPIRE-00133260 Valle, J.W.F.
# 3 Stefan.Sandner.1
# V.F.Domcke.1 Domcke, Valerie
# T.Binder.1 Binder, Tobias
# INSPIRE-00399737 Gustafsson, Michael
# A.Kamada.1 Kamada, Ayuki
# INSPIRE-00491410 Wiesner, Max
# 4 V.Munoz.2
# P.Candia.Da.Silva.1 Candia, Pablo
# G.Cottin.1 Cottin, Giovanna
# A.Mendez.1 Méndez, Andrés
# INSPIRE-00350180 Argüelles Delgado, Carlos Alberto
# INSPIRE-00381280 Kelly, Kevin James
# 0000-0002-4142-2942 Muñoz Albornoz, Víctor
# V.Takhistov.1 Takhistov, Volodymyr
# G.M.Fuller.1 Fuller, George M.
# Ian.M.Shoemaker.1 Shoemaker, Ian M.
# C.A.Arguelles.1 Argüelles, Carlos
# Number of nodes: 169 Number of edges: 189

# %%
# Plot the graph
def plot_graph(namegraph, graph, inigraph=None, k=None):
    fig, ax = plt.subplots(figsize=(20,20))

    pos = nx.spring_layout(graph, k=k, iterations=20)
    nx.draw_networkx(graph, pos=pos, with_labels=True, node_size=10, width=0.1)
    if inigraph!=None:
        nx.draw_networkx(inigraph, pos=pos, node_size=50, node_color="red")#, edge_color="red")

    fig.savefig("inspiregraph_"+namegraph+".pdf")
    plt.show()
    plt.close(fig)

# %%
plot_graph("MyGraph", graph, inigraph, k=0.1)

# %%
# Create a initial list of authors with the SOM group from the IFIC (http://som.ific.uv.es/)
ini_coauths = ini_coauths+["Olga.Mena.1", "P.Hernandez.1", "Veronica.Sanz.1", "J.Lopez.Pavon.1", "A.Donini.1", "C.Hagedorn.1", "Alberto.Ramos.1", "d.g.figueroa.1", "Roberto Ruiz de Austri", "carlos pena-garay", "N.Rius.1", "J.Herrero.Garcia.1"]

# Create their collaboration graph
graph, inigraph = create_coll_graph(ini_coauths, verbose=False)

# Plot only the initial graph (otherwise the plot is too busy)
plot_graph("SOMGraph", inigraph, k=1)
# Out:
# 0 P.Villanueva.Domingo.1
# 1 M.G.Folgado.1
# 2 N.Rius.1
# 3 Stefan.Sandner.1
# 4 V.Munoz.2
# 5 Olga.Mena.1
# Profile Olga.Mena.1 without ids, skipping
# Profile Olga.Mena.1 without ids, skipping
# Profile Olga.Mena.1 without ids, skipping
# 6 P.Hernandez.1
# 7 Veronica.Sanz.1
# 8 J.Lopez.Pavon.1
# 9 A.Donini.1
# Profile A.Donini.1 without ids, skipping
# Profile A.Donini.1 without ids, skipping
# 10 C.Hagedorn.1
# 11 Alberto.Ramos.1
# 12 d.g.figueroa.1
# 13 Roberto Ruiz de Austri
# 14 carlos pena-garay
# 15 N.Rius.1
# 16 J.Herrero.Garcia.1
# Number of nodes: 13593 Number of edges: 16330

# %%
# Create the Einstein's graph
ini_coauths = ["Albert.Einstein.1"]

# Create his collaboration graph up to 5 root authors
graph, inigraph = create_coll_graph(ini_coauths,5)

# Plot the graph
plot_graph("EinsteinGraph", graph, inigraph, k=0.01)
# Out:
# 0 Albert.Einstein.1
# INSPIRE-00000020 Einstein, Albert
# B.Kaufman.2 Kaufman, B.
# E.G.Straus.2 Straus, E.G.
# E.Strauss.1 Strauss, E.G.
# W.Pauli.1 Pauli, W.
# V.Bargmann.1 Bargmann, V.
# P.G.Bergmann.1 Bergmann, P.G.
# L.Infeld.1 Infeld, L.
# B.Hoffmann.2 Hoffmann, B.
# N.Rosen.2 Rosen, N.
# B.Podolsky.1 Podolsky, Boris
# W.de.Sitter.1 de Sitter, W.
# R.C.Tolman.1 Tolman, Richard C.
# A.Gangui.1 Gangui, Alejandro
# E.L.Ortiz.1 Ortiz, Eduardo L.
# A.D.Fokker.1 Fokker, Adriaan D.
# O.Stern.1 Stern, Otto
# 1 INSPIRE-00000020
# 2 B.Kaufman.2
# L.Onsager.1 Onsager, Lars
# 3 E.G.Straus.2
# 4 E.Strauss.1
# Problem reading json data of E.Strauss.1, skipping
# Number of nodes: 19 Number of edges: 23
